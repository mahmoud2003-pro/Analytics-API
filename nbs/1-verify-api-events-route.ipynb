# %%
import requests

# %%
path = "/api/events/"
base_url = "http://localhost:8000"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8000/api/events/'

# %%
response = requests.get(endpoint)
print(response.ok)
# Out:
# True

# %%
if response.ok:
    data = response.json()
    print(data)
# Out:
# {'items': [{'id': 1}, {'id': 2}, {'id': 3}]}

# %%
data = {"page": "/test+"}

# %%
import json

json_data = json.dumps(data)
json_data
# Out:
# '{"page": "/test+"}'

# %%
headers = {'Content-Type': 'application/json'}
response = requests.post(endpoint, data=json_data, headers=headers) # HTTP POST
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print('Error:', response.status_code, response.text)
# Out:
# {'date': 'Tue, 04 Aug 2026 08:25:36 GMT', 'server': 'uvicorn', 'content-length': '10', 'content-type': 'application/json'}
# ok True
# {'id': 123} <class 'dict'> None

# %%
detail_path = "/api/events/12/"
detail_endpoint = f"{base_url}{detail_path}"

headers = {'Content-Type': 'application/json'}
response = requests.put(detail_endpoint, json={"description": "Hello world"}) # HTTP PUT
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print('Error:', response.status_code, response.text)
# Out:
# {'date': 'Tue, 04 Aug 2026 08:34:25 GMT', 'server': 'uvicorn', 'content-length': '9', 'content-type': 'application/json'}
# ok True
# {'id': 12} <class 'dict'> None
