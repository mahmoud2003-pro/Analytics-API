# %%
import requests

# %%
data = {"page": "/test+"}

# %%
import json

json_data = json.dumps(data)
json_data
# Out:
# '{"page": "/test+"}'

# %%
path = "/api/events/"
base_url = "http://localhost:8000"
create_endpoint = f"{base_url}{path}"

headers = {'Content-Type': 'application/json'}
response = requests.post(create_endpoint, data=json_data, headers=headers) # HTTP POST
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print('Error:', response.status_code, response.text)
# Out:
# {'date': 'Thu, 06 Aug 2026 08:37:23 GMT', 'server': 'uvicorn', 'content-length': '43', 'content-type': 'application/json'}
# ok True
# {'id': 123, 'page': '/test+', 'description': ''} <class 'dict'> None

# %%
detail_path = "/api/events/12/"
detail_endpoint = f"{base_url}{detail_path}"

headers = {'Content-Type': 'application/json'}
response = requests.put(detail_endpoint, json={"description": "Hello world"}) # HTTP PUT
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print('Error:', response.status_code, response.text)
# Out:
# {'date': 'Thu, 06 Aug 2026 08:37:23 GMT', 'server': 'uvicorn', 'content-length': '47', 'content-type': 'application/json'}
# ok True
# {'id': 12, 'page': '', 'description': 'Hello world'} <class 'dict'> None
